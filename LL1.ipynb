# %%
class Lexer:
    def __init__(self, input_string):
        self.tokens = self.tokenize(input_string)
        self.current_index = 0

    def tokenize(self, input_string):
        terminal_symbols = [",", ")", "(", "true", "false", "*", "/", "+", "-", "or", "and", "not", "end", "const", "def", "=", "<", ">"]
        words = input_string.split()
        tokens = []

        for i, word in enumerate(words):
            if word.isdigit():
                tokens.append("const")
            elif word not in terminal_symbols:
                tokens.append("def" if (i + 1 < len(words) and words[i + 1] == "(") else "var")
            else:
                tokens.append(word)

        tokens.append("end")
        return tokens

    def get_current_token(self):
        if self.current_index < len(self.tokens):
            return self.tokens[self.current_index]
        return None

    def accept(self, symbol):
        current_token = self.get_current_token()
        if current_token == symbol:
            self.current_index += 1
            return True
        return False

    def error(self, symbol, valid_symbols):
        if not self.check(symbol, valid_symbols):
            raise ValueError("ERROR")

    def check(self, symbol, valid_symbols):
      return symbol in valid_symbols

# %%
class Stack:
    def __init__(self):
        self.stack = []

    def push(self, value):
        self.stack.append(value)

    def pop(self):
        if not self.is_empty():
            return self.stack.pop()
        return None

    def is_empty(self):
        return len(self.stack) == 0

    def __repr__(self):
        return str(self.stack)

# %%
class IState:
    def execute(self):
      pass

class ZeroState(IState):
    def __init__(self, current_state, symbol, next_state, stack, lexer, valid_tokens):
        self.current_state = current_state
        self.symbol = symbol
        self.next_state = next_state
        self.stack = stack
        self.lexer = lexer

    def execute(self):
        return self.next_state
    
class ErrorState(IState):
    def __init__(self, current_state, symbol, next_state, stack, lexer, valid_tokens):
        self.current_state = current_state
        self.symbol = symbol
        self.next_state = next_state
        self.stack = stack
        self.lexer = lexer
        self.valid_tokens = valid_tokens

    def execute(self):
        self.lexer.error(self.symbol, self.valid_tokens)
        return self.next_state

class StackErrorState(IState):
    def __init__(self, current_state, symbol, next_state, stack, lexer, valid_tokens):
        self.current_state = current_state
        self.symbol = symbol
        self.next_state = next_state
        self.stack = stack
        self.lexer = lexer
        self.valid_tokens = valid_tokens

    def execute(self):
        self.lexer.error(self.symbol, self.valid_tokens)
        print(f"Pushing to stack: {self.current_state}")
        self.stack.push(self.current_state + 1)
        return self.next_state


class ReturnErrorState(IState):
    def __init__(self, current_state, symbol, next_state, stack, lexer, valid_tokens):
        self.current_state = current_state
        self.symbol = symbol
        self.next_state = next_state
        self.stack = stack
        self.lexer = lexer
        self.valid_tokens = valid_tokens

    def execute(self):
        self.lexer.error(self.symbol, self.valid_tokens)
        stack_value = self.stack.pop() if not self.stack.is_empty() else self.next_state
        print(f"Popping from stack: {stack_value}")
        return stack_value
    
class AcceptErrorState(IState):
    def __init__(self, current_state, symbol, next_state, stack, lexer, valid_tokens):
        self.current_state = current_state
        self.symbol = symbol
        self.next_state = next_state
        self.stack = stack
        self.lexer = lexer
        self.valid_tokens = valid_tokens

    def execute(self):
        self.lexer.error(self.symbol, self.valid_tokens)
        print(f"ACCEPTING: {self.symbol}")
        self.lexer.accept(self.symbol)
        return self.next_state


class ReturnAcceptErrorState(IState):
    def __init__(self, current_state, symbol, next_state, stack, lexer, valid_tokens):
        self.current_state = current_state
        self.symbol = symbol
        self.next_state = next_state
        self.stack = stack
        self.lexer = lexer
        self.valid_tokens = valid_tokens

    def execute(self):
        self.lexer.error(self.symbol, self.valid_tokens)
        print(f"ACCEPTING: {self.symbol}")
        self.lexer.accept(self.symbol)
        return self.stack.pop() if not self.stack.is_empty() else self.next_state

# %%
class LL1Parser:
    def __init__(self, transitions):
        self.transitions = transitions
        self.state_map = {
            (0, 0, 0, 0): ZeroState,
            (0, 0, 0, 1): ErrorState,
            (0, 1, 0, 1): StackErrorState,
            (0, 0, 1, 1): AcceptErrorState,
            (1, 0, 0, 1): ReturnErrorState,
            (1, 0, 1, 1): ReturnAcceptErrorState
        }
        self.current_state = 1
        self.stack = Stack()
        self.lexer = None

    def process(self, tokens):
        self.lexer = Lexer(" ".join(tokens))
        current_token = self.lexer.get_current_token()
        
        while current_token is not None:
            if current_token == 'end' and self.stack.is_empty():
              print("Parsing complete")
              break

            state_data = self.transitions[self.current_state]
            print(f"State: {self.current_state}\t Token: {current_token}\t Stack: {self.stack}")

            valid_tokens, next_state, attr1, attr2, attr3, attr4 = state_data
            if not self.lexer.check(current_token, valid_tokens):
                if attr4 == 0:
                    print(f"Unexpected symbol '{current_token}', skipping to state {self.current_state + 1}")
                    self.current_state += 1
                    current_token = self.lexer.get_current_token()
                    continue

            state_key = (attr1, attr2, attr3, attr4)
            state_class = self.state_map[state_key]
            state_instance = state_class(self.current_state, current_token, next_state, self.stack, self.lexer, valid_tokens)
            self.current_state = state_instance.execute()
            current_token = self.lexer.get_current_token()

        print("Grammar is true")

# %%
import pandas as pd

df = pd.read_excel("РИС_ЛР_2.xlsx", index_col = "№")
df
# Out:
#           множество направляющих символов  next  return  stack  accept  error
# №
# 1   end ) ( const var  true false not def    29       0      0       0      1
# 2                                       +    31       0      0       0      0
# 3                                       -    34       0      0       0      0
# 4                                   end )    37       0      0       0      1
# 5          ( def var const true false not    38       0      0       0      1
# ..                                    ...   ...     ...    ...     ...    ...
# 85                                      ,    86       0      0       1      1
# 86  end ) ( const var  true false not def    28       0      1       0      1
# 87  end ) ( const var  true false not def    26       0      0       0      1
# 88  end ) ( const var  true false not def    -1       1      0       0      1
# 89  end ) ( const var  true false not def     1       0      0       0      1
#
# [89 rows x 6 columns]

# %%
dictionary = {}
for i in range(1, df.shape[0] + 1):
  dictionary[i] = []
  for j in df.columns:
    dictionary[i].append(df[j][i])

dictionary
# Out:
# {1: ['end ) ( const var  true false not def',
#   np.int64(29),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  2: ['+', np.int64(31), np.int64(0), np.int64(0), np.int64(0), np.int64(0)],
#  3: ['-', np.int64(34), np.int64(0), np.int64(0), np.int64(0), np.int64(0)],
#  4: ['end )',
#   np.int64(37),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  5: ['( def var const true false not',
#   np.int64(38),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  6: ['*', np.int64(40), np.int64(0), np.int64(0), np.int64(0), np.int64(0)],
#  7: ['/', np.int64(43), np.int64(0), np.int64(0), np.int64(0), np.int64(0)],
#  8: ['end ) + -',
#   np.int64(46),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  9: ['( def var const true false not',
#   np.int64(47),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  10: [',', np.int64(49), np.int64(0), np.int64(0), np.int64(0), np.int64(0)],
#  11: ['<', np.int64(52), np.int64(0), np.int64(0), np.int64(0), np.int64(0)],
#  12: ['>', np.int64(55), np.int64(0), np.int64(0), np.int64(0), np.int64(0)],
#  13: ['=', np.int64(58), np.int64(0), np.int64(0), np.int64(0), np.int64(0)],
#  14: [', < > = end ) + - * /',
#   np.int64(61),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  15: ['true false not',
#   np.int64(62),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0)],
#  16: ['def', np.int64(64), np.int64(0), np.int64(0), np.int64(0), np.int64(0)],
#  17: ['var', np.int64(69), np.int64(0), np.int64(0), np.int64(0), np.int64(0)],
#  18: ['const',
#   np.int64(70),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0)],
#  19: ['(', np.int64(71), np.int64(0), np.int64(0), np.int64(0), np.int64(1)],
#  20: ['and', np.int64(74), np.int64(0), np.int64(0), np.int64(0), np.int64(0)],
#  21: ['or', np.int64(77), np.int64(0), np.int64(0), np.int64(0), np.int64(0)],
#  22: ['and or not ) end',
#   np.int64(80),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  23: ['true',
#   np.int64(81),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0)],
#  24: ['false',
#   np.int64(82),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0)],
#  25: ['not', np.int64(83), np.int64(0), np.int64(0), np.int64(0), np.int64(1)],
#  26: [',', np.int64(85), np.int64(0), np.int64(0), np.int64(0), np.int64(0)],
#  27: ['end )',
#   np.int64(88),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  28: ['end ) ( const var  true false not def',
#   np.int64(89),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  29: ['( def var const true false not',
#   np.int64(5),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  30: ['end + - ) ',
#   np.int64(2),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  31: ['+', np.int64(32), np.int64(0), np.int64(0), np.int64(1), np.int64(1)],
#  32: ['( def var const',
#   np.int64(5),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  33: ['end + - )',
#   np.int64(2),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  34: ['-', np.int64(35), np.int64(0), np.int64(0), np.int64(1), np.int64(1)],
#  35: ['( def var const',
#   np.int64(5),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  36: ['end + - ) ',
#   np.int64(2),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  37: ['end )',
#   np.int64(-1),
#   np.int64(1),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  38: ['( def var const true false not',
#   np.int64(9),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  39: ['end ) * / + - ',
#   np.int64(6),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  40: ['*', np.int64(41), np.int64(0), np.int64(0), np.int64(1), np.int64(1)],
#  41: ['( def var const true false not',
#   np.int64(9),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  42: ['end + - ) * /',
#   np.int64(6),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  43: ['/', np.int64(44), np.int64(0), np.int64(0), np.int64(1), np.int64(1)],
#  44: ['( def var const true false not',
#   np.int64(9),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  45: ['end + - ) * /',
#   np.int64(6),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  46: ['end + - ) * /',
#   np.int64(-1),
#   np.int64(1),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  47: ['( def var const true false not',
#   np.int64(15),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  48: [', < > = ( def var const true false not end + - ) * / and or',
#   np.int64(10),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  49: [',', np.int64(50), np.int64(0), np.int64(0), np.int64(1), np.int64(1)],
#  50: ['( def perem const true false not',
#   np.int64(15),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  51: [', < > = ( def var const true false not end + - ) * / and or',
#   np.int64(10),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  52: ['<', np.int64(53), np.int64(0), np.int64(0), np.int64(1), np.int64(1)],
#  53: ['( def var const true false not',
#   np.int64(15),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  54: [', < > = ( def var const true false not end + - ) * / and or',
#   np.int64(10),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  55: ['>', np.int64(56), np.int64(0), np.int64(0), np.int64(1), np.int64(1)],
#  56: ['( def var const true false not',
#   np.int64(15),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  57: [', < > = ( def var const true false not end + - ) * / and or',
#   np.int64(10),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  58: ['=', np.int64(59), np.int64(0), np.int64(0), np.int64(1), np.int64(1)],
#  59: ['( def var const true false not',
#   np.int64(15),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  60: [', < > = ( def var const true false not end + - ) * / and or',
#   np.int64(10),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  61: [', < > = ( def var const true false not end + - ) * / and or',
#   np.int64(-1),
#   np.int64(1),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  62: ['true false not and or',
#   np.int64(23),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  63: ['true false not and or end )',
#   np.int64(20),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  64: ['def', np.int64(65), np.int64(0), np.int64(0), np.int64(1), np.int64(1)],
#  65: ['(', np.int64(66), np.int64(0), np.int64(0), np.int64(1), np.int64(1)],
#  66: ['end ( const var  true false not def',
#   np.int64(89),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  67: ['end ) const var  true false not def',
#   np.int64(26),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  68: [')', np.int64(-1), np.int64(1), np.int64(0), np.int64(1), np.int64(1)],
#  69: ['var', np.int64(-1), np.int64(1), np.int64(0), np.int64(1), np.int64(1)],
#  70: ['const',
#   np.int64(-1),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1),
#   np.int64(1)],
#  71: ['(', np.int64(72), np.int64(0), np.int64(0), np.int64(1), np.int64(1)],
#  72: ['end ) ( const var  true false not def',
#   np.int64(1),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  73: [')', np.int64(-1), np.int64(1), np.int64(0), np.int64(1), np.int64(1)],
#  74: ['and', np.int64(75), np.int64(0), np.int64(0), np.int64(1), np.int64(1)],
#  75: ['true false not',
#   np.int64(23),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  76: [') end and or true false',
#   np.int64(20),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  77: ['or', np.int64(78), np.int64(0), np.int64(0), np.int64(1), np.int64(1)],
#  78: ['true false not',
#   np.int64(23),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  79: [') end and or true false',
#   np.int64(20),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  80: [') end and or true false',
#   np.int64(-1),
#   np.int64(1),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  81: ['true',
#   np.int64(-1),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1),
#   np.int64(1)],
#  82: ['false',
#   np.int64(-1),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1),
#   np.int64(1)],
#  83: ['not', np.int64(84), np.int64(0), np.int64(0), np.int64(1), np.int64(1)],
#  84: ['true false not',
#   np.int64(23),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  85: [',', np.int64(86), np.int64(0), np.int64(0), np.int64(1), np.int64(1)],
#  86: ['end ) ( const var  true false not def',
#   np.int64(28),
#   np.int64(0),
#   np.int64(1),
#   np.int64(0),
#   np.int64(1)],
#  87: ['end ) ( const var  true false not def',
#   np.int64(26),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  88: ['end ) ( const var  true false not def',
#   np.int64(-1),
#   np.int64(1),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)],
#  89: ['end ) ( const var  true false not def',
#   np.int64(1),
#   np.int64(0),
#   np.int64(0),
#   np.int64(0),
#   np.int64(1)]}

# %%
input = "27 - 10 * ( 10 + 6 / 7 - ( 30 - 2 ) )"
lexer = Lexer(input)
tokens = lexer.tokens
ll1 = LL1Parser(dictionary)
print(f"\nINPUT: {input}")
print("----------------------------")
ll1.process(tokens)
# Out:
# INPUT: 27 - 10 * ( 10 + 6 / 7 - ( 30 - 2 ) )
# ----------------------------
# State: 1	 Token: const	 Stack: []
# State: 29	 Token: const	 Stack: []
# Pushing to stack: 29
# State: 5	 Token: const	 Stack: [np.int64(30)]
# State: 38	 Token: const	 Stack: [np.int64(30)]
# Pushing to stack: 38
# State: 9	 Token: const	 Stack: [np.int64(30), np.int64(39)]
# State: 47	 Token: const	 Stack: [np.int64(30), np.int64(39)]
# Pushing to stack: 47
# State: 15	 Token: const	 Stack: [np.int64(30), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 16
# State: 16	 Token: const	 Stack: [np.int64(30), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 17
# State: 17	 Token: const	 Stack: [np.int64(30), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 18
# State: 18	 Token: const	 Stack: [np.int64(30), np.int64(39), np.int64(48)]
# State: 70	 Token: const	 Stack: [np.int64(30), np.int64(39), np.int64(48)]
# ACCEPTING: const
# State: 48	 Token: -	 Stack: [np.int64(30), np.int64(39)]
# State: 10	 Token: -	 Stack: [np.int64(30), np.int64(39)]
# Unexpected symbol '-', skipping to state 11
# State: 11	 Token: -	 Stack: [np.int64(30), np.int64(39)]
# Unexpected symbol '-', skipping to state 12
# State: 12	 Token: -	 Stack: [np.int64(30), np.int64(39)]
# Unexpected symbol '-', skipping to state 13
# State: 13	 Token: -	 Stack: [np.int64(30), np.int64(39)]
# Unexpected symbol '-', skipping to state 14
# State: 14	 Token: -	 Stack: [np.int64(30), np.int64(39)]
# State: 61	 Token: -	 Stack: [np.int64(30), np.int64(39)]
# Popping from stack: 39
# State: 39	 Token: -	 Stack: [np.int64(30)]
# State: 6	 Token: -	 Stack: [np.int64(30)]
# Unexpected symbol '-', skipping to state 7
# State: 7	 Token: -	 Stack: [np.int64(30)]
# Unexpected symbol '-', skipping to state 8
# State: 8	 Token: -	 Stack: [np.int64(30)]
# State: 46	 Token: -	 Stack: [np.int64(30)]
# Popping from stack: 30
# State: 30	 Token: -	 Stack: []
# State: 2	 Token: -	 Stack: []
# Unexpected symbol '-', skipping to state 3
# State: 3	 Token: -	 Stack: []
# State: 34	 Token: -	 Stack: []
# ACCEPTING: -
# State: 35	 Token: const	 Stack: []
# Pushing to stack: 35
# State: 5	 Token: const	 Stack: [np.int64(36)]
# State: 38	 Token: const	 Stack: [np.int64(36)]
# Pushing to stack: 38
# State: 9	 Token: const	 Stack: [np.int64(36), np.int64(39)]
# State: 47	 Token: const	 Stack: [np.int64(36), np.int64(39)]
# Pushing to stack: 47
# State: 15	 Token: const	 Stack: [np.int64(36), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 16
# State: 16	 Token: const	 Stack: [np.int64(36), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 17
# State: 17	 Token: const	 Stack: [np.int64(36), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 18
# State: 18	 Token: const	 Stack: [np.int64(36), np.int64(39), np.int64(48)]
# State: 70	 Token: const	 Stack: [np.int64(36), np.int64(39), np.int64(48)]
# ACCEPTING: const
# State: 48	 Token: *	 Stack: [np.int64(36), np.int64(39)]
# State: 10	 Token: *	 Stack: [np.int64(36), np.int64(39)]
# Unexpected symbol '*', skipping to state 11
# State: 11	 Token: *	 Stack: [np.int64(36), np.int64(39)]
# Unexpected symbol '*', skipping to state 12
# State: 12	 Token: *	 Stack: [np.int64(36), np.int64(39)]
# Unexpected symbol '*', skipping to state 13
# State: 13	 Token: *	 Stack: [np.int64(36), np.int64(39)]
# Unexpected symbol '*', skipping to state 14
# State: 14	 Token: *	 Stack: [np.int64(36), np.int64(39)]
# State: 61	 Token: *	 Stack: [np.int64(36), np.int64(39)]
# Popping from stack: 39
# State: 39	 Token: *	 Stack: [np.int64(36)]
# State: 6	 Token: *	 Stack: [np.int64(36)]
# State: 40	 Token: *	 Stack: [np.int64(36)]
# ACCEPTING: *
# State: 41	 Token: (	 Stack: [np.int64(36)]
# Pushing to stack: 41
# State: 9	 Token: (	 Stack: [np.int64(36), np.int64(42)]
# State: 47	 Token: (	 Stack: [np.int64(36), np.int64(42)]
# Pushing to stack: 47
# State: 15	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48)]
# Unexpected symbol '(', skipping to state 16
# State: 16	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48)]
# Unexpected symbol '(', skipping to state 17
# State: 17	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48)]
# Unexpected symbol '(', skipping to state 18
# State: 18	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48)]
# Unexpected symbol '(', skipping to state 19
# State: 19	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48)]
# State: 71	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48)]
# ACCEPTING: (
# State: 72	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48)]
# Pushing to stack: 72
# State: 1	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# State: 29	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# Pushing to stack: 29
# State: 5	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30)]
# State: 38	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30)]
# Pushing to stack: 38
# State: 9	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# State: 47	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# Pushing to stack: 47
# State: 15	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 16
# State: 16	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 17
# State: 17	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 18
# State: 18	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30), np.int64(39), np.int64(48)]
# State: 70	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30), np.int64(39), np.int64(48)]
# ACCEPTING: const
# State: 48	 Token: +	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# State: 10	 Token: +	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# Unexpected symbol '+', skipping to state 11
# State: 11	 Token: +	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# Unexpected symbol '+', skipping to state 12
# State: 12	 Token: +	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# Unexpected symbol '+', skipping to state 13
# State: 13	 Token: +	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# Unexpected symbol '+', skipping to state 14
# State: 14	 Token: +	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# State: 61	 Token: +	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# Popping from stack: 39
# State: 39	 Token: +	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30)]
# State: 6	 Token: +	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30)]
# Unexpected symbol '+', skipping to state 7
# State: 7	 Token: +	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30)]
# Unexpected symbol '+', skipping to state 8
# State: 8	 Token: +	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30)]
# State: 46	 Token: +	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(30)]
# Popping from stack: 30
# State: 30	 Token: +	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# State: 2	 Token: +	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# State: 31	 Token: +	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# ACCEPTING: +
# State: 32	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# Pushing to stack: 32
# State: 5	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33)]
# State: 38	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33)]
# Pushing to stack: 38
# State: 9	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(39)]
# State: 47	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(39)]
# Pushing to stack: 47
# State: 15	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 16
# State: 16	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 17
# State: 17	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 18
# State: 18	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(39), np.int64(48)]
# State: 70	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(39), np.int64(48)]
# ACCEPTING: const
# State: 48	 Token: /	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(39)]
# State: 10	 Token: /	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(39)]
# Unexpected symbol '/', skipping to state 11
# State: 11	 Token: /	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(39)]
# Unexpected symbol '/', skipping to state 12
# State: 12	 Token: /	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(39)]
# Unexpected symbol '/', skipping to state 13
# State: 13	 Token: /	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(39)]
# Unexpected symbol '/', skipping to state 14
# State: 14	 Token: /	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(39)]
# State: 61	 Token: /	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(39)]
# Popping from stack: 39
# State: 39	 Token: /	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33)]
# State: 6	 Token: /	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33)]
# Unexpected symbol '/', skipping to state 7
# State: 7	 Token: /	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33)]
# State: 43	 Token: /	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33)]
# ACCEPTING: /
# State: 44	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33)]
# Pushing to stack: 44
# State: 9	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(45)]
# State: 47	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(45)]
# Pushing to stack: 47
# State: 15	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(45), np.int64(48)]
# Unexpected symbol 'const', skipping to state 16
# State: 16	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(45), np.int64(48)]
# Unexpected symbol 'const', skipping to state 17
# State: 17	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(45), np.int64(48)]
# Unexpected symbol 'const', skipping to state 18
# State: 18	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(45), np.int64(48)]
# State: 70	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(45), np.int64(48)]
# ACCEPTING: const
# State: 48	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(45)]
# State: 10	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(45)]
# Unexpected symbol '-', skipping to state 11
# State: 11	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(45)]
# Unexpected symbol '-', skipping to state 12
# State: 12	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(45)]
# Unexpected symbol '-', skipping to state 13
# State: 13	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(45)]
# Unexpected symbol '-', skipping to state 14
# State: 14	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(45)]
# State: 61	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33), np.int64(45)]
# Popping from stack: 45
# State: 45	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33)]
# State: 6	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33)]
# Unexpected symbol '-', skipping to state 7
# State: 7	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33)]
# Unexpected symbol '-', skipping to state 8
# State: 8	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33)]
# State: 46	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(33)]
# Popping from stack: 33
# State: 33	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# State: 2	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# Unexpected symbol '-', skipping to state 3
# State: 3	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# State: 34	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# ACCEPTING: -
# State: 35	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# Pushing to stack: 35
# State: 5	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36)]
# State: 38	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36)]
# Pushing to stack: 38
# State: 9	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# State: 47	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# Pushing to stack: 47
# State: 15	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48)]
# Unexpected symbol '(', skipping to state 16
# State: 16	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48)]
# Unexpected symbol '(', skipping to state 17
# State: 17	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48)]
# Unexpected symbol '(', skipping to state 18
# State: 18	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48)]
# Unexpected symbol '(', skipping to state 19
# State: 19	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48)]
# State: 71	 Token: (	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48)]
# ACCEPTING: (
# State: 72	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48)]
# Pushing to stack: 72
# State: 1	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73)]
# State: 29	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73)]
# Pushing to stack: 29
# State: 5	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30)]
# State: 38	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30)]
# Pushing to stack: 38
# State: 9	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# State: 47	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# Pushing to stack: 47
# State: 15	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 16
# State: 16	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 17
# State: 17	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 18
# State: 18	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30), np.int64(39), np.int64(48)]
# State: 70	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30), np.int64(39), np.int64(48)]
# ACCEPTING: const
# State: 48	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# State: 10	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# Unexpected symbol '-', skipping to state 11
# State: 11	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# Unexpected symbol '-', skipping to state 12
# State: 12	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# Unexpected symbol '-', skipping to state 13
# State: 13	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# Unexpected symbol '-', skipping to state 14
# State: 14	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# State: 61	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30), np.int64(39)]
# Popping from stack: 39
# State: 39	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30)]
# State: 6	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30)]
# Unexpected symbol '-', skipping to state 7
# State: 7	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30)]
# Unexpected symbol '-', skipping to state 8
# State: 8	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30)]
# State: 46	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(30)]
# Popping from stack: 30
# State: 30	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73)]
# State: 2	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73)]
# Unexpected symbol '-', skipping to state 3
# State: 3	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73)]
# State: 34	 Token: -	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73)]
# ACCEPTING: -
# State: 35	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73)]
# Pushing to stack: 35
# State: 5	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36)]
# State: 38	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36)]
# Pushing to stack: 38
# State: 9	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# State: 47	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# Pushing to stack: 47
# State: 15	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 16
# State: 16	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 17
# State: 17	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 18
# State: 18	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48)]
# State: 70	 Token: const	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48)]
# ACCEPTING: const
# State: 48	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# State: 10	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# Unexpected symbol ')', skipping to state 11
# State: 11	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# Unexpected symbol ')', skipping to state 12
# State: 12	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# Unexpected symbol ')', skipping to state 13
# State: 13	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# Unexpected symbol ')', skipping to state 14
# State: 14	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# State: 61	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# Popping from stack: 39
# State: 39	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36)]
# State: 6	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36)]
# Unexpected symbol ')', skipping to state 7
# State: 7	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36)]
# Unexpected symbol ')', skipping to state 8
# State: 8	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36)]
# State: 46	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73), np.int64(36)]
# Popping from stack: 36
# State: 36	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73)]
# State: 2	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73)]
# Unexpected symbol ')', skipping to state 3
# State: 3	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73)]
# Unexpected symbol ')', skipping to state 4
# State: 4	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73)]
# State: 37	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48), np.int64(73)]
# Popping from stack: 73
# State: 73	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39), np.int64(48)]
# ACCEPTING: )
# State: 48	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# State: 10	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# Unexpected symbol ')', skipping to state 11
# State: 11	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# Unexpected symbol ')', skipping to state 12
# State: 12	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# Unexpected symbol ')', skipping to state 13
# State: 13	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# Unexpected symbol ')', skipping to state 14
# State: 14	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# State: 61	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36), np.int64(39)]
# Popping from stack: 39
# State: 39	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36)]
# State: 6	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36)]
# Unexpected symbol ')', skipping to state 7
# State: 7	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36)]
# Unexpected symbol ')', skipping to state 8
# State: 8	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36)]
# State: 46	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73), np.int64(36)]
# Popping from stack: 36
# State: 36	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# State: 2	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# Unexpected symbol ')', skipping to state 3
# State: 3	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# Unexpected symbol ')', skipping to state 4
# State: 4	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# State: 37	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48), np.int64(73)]
# Popping from stack: 73
# State: 73	 Token: )	 Stack: [np.int64(36), np.int64(42), np.int64(48)]
# ACCEPTING: )
# State: 48	 Token: end	 Stack: [np.int64(36), np.int64(42)]
# State: 10	 Token: end	 Stack: [np.int64(36), np.int64(42)]
# Unexpected symbol 'end', skipping to state 11
# State: 11	 Token: end	 Stack: [np.int64(36), np.int64(42)]
# Unexpected symbol 'end', skipping to state 12
# State: 12	 Token: end	 Stack: [np.int64(36), np.int64(42)]
# Unexpected symbol 'end', skipping to state 13
# State: 13	 Token: end	 Stack: [np.int64(36), np.int64(42)]
# Unexpected symbol 'end', skipping to state 14
# State: 14	 Token: end	 Stack: [np.int64(36), np.int64(42)]
# State: 61	 Token: end	 Stack: [np.int64(36), np.int64(42)]
# Popping from stack: 42
# State: 42	 Token: end	 Stack: [np.int64(36)]
# State: 6	 Token: end	 Stack: [np.int64(36)]
# Unexpected symbol 'end', skipping to state 7
# State: 7	 Token: end	 Stack: [np.int64(36)]
# Unexpected symbol 'end', skipping to state 8
# State: 8	 Token: end	 Stack: [np.int64(36)]
# State: 46	 Token: end	 Stack: [np.int64(36)]
# Popping from stack: 36
# Parsing complete
# Grammar is true

# %%
input = "20 * 2 /"
lexer = Lexer(input)
tokens = lexer.tokens
ll1 = LL1Parser(dictionary)
print(f"\nINPUT: {input}")
print("----------------------------")
ll1.process(tokens)
# Out:
# INPUT: 20 * 2 /
# ----------------------------
# State: 1	 Token: const	 Stack: []
# State: 29	 Token: const	 Stack: []
# Pushing to stack: 29
# State: 5	 Token: const	 Stack: [np.int64(30)]
# State: 38	 Token: const	 Stack: [np.int64(30)]
# Pushing to stack: 38
# State: 9	 Token: const	 Stack: [np.int64(30), np.int64(39)]
# State: 47	 Token: const	 Stack: [np.int64(30), np.int64(39)]
# Pushing to stack: 47
# State: 15	 Token: const	 Stack: [np.int64(30), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 16
# State: 16	 Token: const	 Stack: [np.int64(30), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 17
# State: 17	 Token: const	 Stack: [np.int64(30), np.int64(39), np.int64(48)]
# Unexpected symbol 'const', skipping to state 18
# State: 18	 Token: const	 Stack: [np.int64(30), np.int64(39), np.int64(48)]
# State: 70	 Token: const	 Stack: [np.int64(30), np.int64(39), np.int64(48)]
# ACCEPTING: const
# State: 48	 Token: *	 Stack: [np.int64(30), np.int64(39)]
# State: 10	 Token: *	 Stack: [np.int64(30), np.int64(39)]
# Unexpected symbol '*', skipping to state 11
# State: 11	 Token: *	 Stack: [np.int64(30), np.int64(39)]
# Unexpected symbol '*', skipping to state 12
# State: 12	 Token: *	 Stack: [np.int64(30), np.int64(39)]
# Unexpected symbol '*', skipping to state 13
# State: 13	 Token: *	 Stack: [np.int64(30), np.int64(39)]
# Unexpected symbol '*', skipping to state 14
# State: 14	 Token: *	 Stack: [np.int64(30), np.int64(39)]
# State: 61	 Token: *	 Stack: [np.int64(30), np.int64(39)]
# Popping from stack: 39
# State: 39	 Token: *	 Stack: [np.int64(30)]
# State: 6	 Token: *	 Stack: [np.int64(30)]
# State: 40	 Token: *	 Stack: [np.int64(30)]
# ACCEPTING: *
# State: 41	 Token: const	 Stack: [np.int64(30)]
# Pushing to stack: 41
# State: 9	 Token: const	 Stack: [np.int64(30), np.int64(42)]
# State: 47	 Token: const	 Stack: [np.int64(30), np.int64(42)]
# Pushing to stack: 47
# State: 15	 Token: const	 Stack: [np.int64(30), np.int64(42), np.int64(48)]
# Unexpected symbol 'const', skipping to state 16
# State: 16	 Token: const	 Stack: [np.int64(30), np.int64(42), np.int64(48)]
# Unexpected symbol 'const', skipping to state 17
# State: 17	 Token: const	 Stack: [np.int64(30), np.int64(42), np.int64(48)]
# Unexpected symbol 'const', skipping to state 18
# State: 18	 Token: const	 Stack: [np.int64(30), np.int64(42), np.int64(48)]
# State: 70	 Token: const	 Stack: [np.int64(30), np.int64(42), np.int64(48)]
# ACCEPTING: const
# State: 48	 Token: /	 Stack: [np.int64(30), np.int64(42)]
# State: 10	 Token: /	 Stack: [np.int64(30), np.int64(42)]
# Unexpected symbol '/', skipping to state 11
# State: 11	 Token: /	 Stack: [np.int64(30), np.int64(42)]
# Unexpected symbol '/', skipping to state 12
# State: 12	 Token: /	 Stack: [np.int64(30), np.int64(42)]
# Unexpected symbol '/', skipping to state 13
# State: 13	 Token: /	 Stack: [np.int64(30), np.int64(42)]
# Unexpected symbol '/', skipping to state 14
# State: 14	 Token: /	 Stack: [np.int64(30), np.int64(42)]
# State: 61	 Token: /	 Stack: [np.int64(30), np.int64(42)]
# Popping from stack: 42
# State: 42	 Token: /	 Stack: [np.int64(30)]
# State: 6	 Token: /	 Stack: [np.int64(30)]
# Unexpected symbol '/', skipping to state 7
# State: 7	 Token: /	 Stack: [np.int64(30)]
# State: 43	 Token: /	 Stack: [np.int64(30)]
# ACCEPTING: /
# State: 44	 Token: end	 Stack: [np.int64(30)]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\University\4 КУРС\Разработка ИС\Лабы\DevelopmentIS\LL1.ipynb Cell 8 line 7
#       <a href='vscode-notebook-cell:/d%3A/University/4%20%D0%9A%D0%A3%D0%A0%D0%A1/%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%98%D0%A1/%D0%9B%D0%B0%D0%B1%D1%8B/DevelopmentIS/LL1.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> print(f"\nINPUT: {input}")
#       <a href='vscode-notebook-cell:/d%3A/University/4%20%D0%9A%D0%A3%D0%A0%D0%A1/%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%98%D0%A1/%D0%9B%D0%B0%D0%B1%D1%8B/DevelopmentIS/LL1.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a> print("----------------------------")
# ----> <a href='vscode-notebook-cell:/d%3A/University/4%20%D0%9A%D0%A3%D0%A0%D0%A1/%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%98%D0%A1/%D0%9B%D0%B0%D0%B1%D1%8B/DevelopmentIS/LL1.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a> ll1.process(tokens)
#
# d:\University\4 КУРС\Разработка ИС\Лабы\DevelopmentIS\LL1.ipynb Cell 8 line 3
#      <a href='vscode-notebook-cell:/d%3A/University/4%20%D0%9A%D0%A3%D0%A0%D0%A1/%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%98%D0%A1/%D0%9B%D0%B0%D0%B1%D1%8B/DevelopmentIS/LL1.ipynb#X10sZmlsZQ%3D%3D?line=36'>37</a>     state_class = self.state_map[state_key]
#      <a href='vscode-notebook-cell:/d%3A/University/4%20%D0%9A%D0%A3%D0%A0%D0%A1/%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%98%D0%A1/%D0%9B%D0%B0%D0%B1%D1%8B/DevelopmentIS/LL1.ipynb#X10sZmlsZQ%3D%3D?line=37'>38</a>     state_instance = state_class(self.current_state, current_token, next_state, self.stack, self.lexer, valid_tokens)
# ---> <a href='vscode-notebook-cell:/d%3A/University/4%20%D0%9A%D0%A3%D0%A0%D0%A1/%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%98%D0%A1/%D0%9B%D0%B0%D0%B1%D1%8B/DevelopmentIS/LL1.ipynb#X10sZmlsZQ%3D%3D?line=38'>39</a>     self.current_state = state_instance.execute()
#      <a href='vscode-notebook-cell:/d%3A/University/4%20%D0%9A%D0%A3%D0%A0%D0%A1/%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%98%D0%A1/%D0%9B%D0%B0%D0%B1%D1%8B/DevelopmentIS/LL1.ipynb#X10sZmlsZQ%3D%3D?line=39'>40</a>     current_token = self.lexer.get_current_token()
#      <a href='vscode-notebook-cell:/d%3A/University/4%20%D0%9A%D0%A3%D0%A0%D0%A1/%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%98%D0%A1/%D0%9B%D0%B0%D0%B1%D1%8B/DevelopmentIS/LL1.ipynb#X10sZmlsZQ%3D%3D?line=41'>42</a> print("Grammar is true")
#
# d:\University\4 КУРС\Разработка ИС\Лабы\DevelopmentIS\LL1.ipynb Cell 8 line 3
#      <a href='vscode-notebook-cell:/d%3A/University/4%20%D0%9A%D0%A3%D0%A0%D0%A1/%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%98%D0%A1/%D0%9B%D0%B0%D0%B1%D1%8B/DevelopmentIS/LL1.ipynb#X10sZmlsZQ%3D%3D?line=37'>38</a> def execute(self):
# ---> <a href='vscode-notebook-cell:/d%3A/University/4%20%D0%9A%D0%A3%D0%A0%D0%A1/%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%98%D0%A1/%D0%9B%D0%B0%D0%B1%D1%8B/DevelopmentIS/LL1.ipynb#X10sZmlsZQ%3D%3D?line=38'>39</a>     self.lexer.error(self.symbol, self.valid_tokens)
#      <a href='vscode-notebook-cell:/d%3A/University/4%20%D0%9A%D0%A3%D0%A0%D0%A1/%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%98%D0%A1/%D0%9B%D0%B0%D0%B1%D1%8B/DevelopmentIS/LL1.ipynb#X10sZmlsZQ%3D%3D?line=39'>40</a>     print(f"Pushing to stack: {self.current_state}")
#      <a href='vscode-notebook-cell:/d%3A/University/4%20%D0%9A%D0%A3%D0%A0%D0%A1/%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%98%D0%A1/%D0%9B%D0%B0%D0%B1%D1%8B/DevelopmentIS/LL1.ipynb#X10sZmlsZQ%3D%3D?line=40'>41</a>     self.stack.push(self.current_state + 1)
#
# d:\University\4 КУРС\Разработка ИС\Лабы\DevelopmentIS\LL1.ipynb Cell 8 line 3
#      <a href='vscode-notebook-cell:/d%3A/University/4%20%D0%9A%D0%A3%D0%A0%D0%A1/%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%98%D0%A1/%D0%9B%D0%B0%D0%B1%D1%8B/DevelopmentIS/LL1.ipynb#X10sZmlsZQ%3D%3D?line=33'>34</a> def error(self, symbol, valid_symbols):
#      <a href='vscode-notebook-cell:/d%3A/University/4%20%D0%9A%D0%A3%D0%A0%D0%A1/%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%98%D0%A1/%D0%9B%D0%B0%D0%B1%D1%8B/DevelopmentIS/LL1.ipynb#X10sZmlsZQ%3D%3D?line=34'>35</a>     if not self.check(symbol, valid_symbols):
# ---> <a href='vscode-notebook-cell:/d%3A/University/4%20%D0%9A%D0%A3%D0%A0%D0%A1/%D0%A0%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%98%D0%A1/%D0%9B%D0%B0%D0%B1%D1%8B/DevelopmentIS/LL1.ipynb#X10sZmlsZQ%3D%3D?line=35'>36</a>         raise ValueError("ERROR")
#
# ValueError: ERROR
